# %% [markdown]
# # Automated Compliance Evidence Collector — Master Learning Index
#
# ## Your Bootcamp Curriculum
#
# **Built for:** Jon — AWS DVA-C02 candidate, NIST 800-53 practitioner, aspiring defense-contractor SaaS founder
#
# **Cross-references throughout:**
# - *Designing Data-Intensive Applications* (DDIA) by Martin Kleppmann
# - *System Design Interview* by ByteByteGo (Alex Xu)
# - AWS Certified Developer Associate (DVA-C02) exam domains
# - Your Carolina Cyber & Owl Cyber Defense experience
#
# ---
#
# ## How This Curriculum Works
#
# Each phase builds on the previous one. Theory sections teach concepts with DDIA/DVA-C02 connections. Lab sections have hands-on code that produces working artifacts feeding into the final tool.
#
# **Estimated Total Time:** 60-80 hours across all phases
#
# ---
#
# ## Architecture Overview
#
# ```
#                      COMPLIANCE EVIDENCE COLLECTOR
#
#   Phase 1               Phase 2               Phase 3
#   DATA COLLECTION       CONTROL MAPPING        EVIDENCE PDF
#   ┌──────────────┐     ┌───────────────┐     ┌────────────────┐
#   │ Security Hub │     │ NIST 800-53   │     │ ReportLab +    │
#   │ AWS Config   │────>│ Mapping       │────>│ Jinja2         │
#   │ IAM          │     │ Engine        │     │ PDF Generator  │
#   │ CloudTrail   │     │ (Python)      │     │                │
#   │ GuardDuty    │     └───────┬───────┘     └────────┬───────┘
#   └──────────────┘             │                      │
#          │                     │                      │
#          v                     v                      v
#   Phase 4               Phase 5               evidence_pdfs/
#   DRIFT DETECTION       DASHBOARD              (S3 bucket)
#   ┌──────────────┐     ┌───────────────┐
#   │ Compare      │     │ API Gateway   │
#   │ scans over   │     │ + Lambda      │
#   │ time         │     │ + React/      │
#   │ SNS alerts   │     │   Streamlit   │
#   └──────────────┘     └───────────────┘
#          │                     │
#          └──────────┬──────────┘
#                     v
#   Phase 6: Terraform IaC + CI/CD
#   Phase 7: Demo Environment + Go-to-Market
# ```
#
# ---

# %% [markdown]
# ## Phase 0: Foundations — Compliance Theory & System Architecture
# **Estimated: 6-8 hours** | **Folder:** `phase-0-foundations/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `00-theory-compliance-and-architecture.ipynb` | NIST 800-53 deep dive, FedRAMP baselines, AWS security services primer, full system architecture, data model design | Ch. 1-4, 11 | Domains 1-4 overview |
#
# **Deliverable:** Complete understanding of what you're building and why. Back-of-envelope estimates. DynamoDB schema design.
#
# ---
#
# ## Phase 1: AWS Data Collection Pipeline
# **Estimated: 9-11 hours** | **Folder:** `phase-1-data-collection/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `01-theory-aws-security-apis.ipynb` | ASFF format, Config rules, event-driven architecture, boto3 patterns, IAM policy design | Ch. 3, 4, 11 | Lambda, EventBridge, IAM |
# | `01-lab-building-the-collector.ipynb` | Hands-on: SecurityHubCollector, ConfigCollector, IAMCollector, ComplianceCollector, EvidenceStore, Lambda handler | Ch. 3, 4 | SDK, pagination, error handling |
#
# **Deliverable:** Working Python collectors that pull data from 5 AWS security services.
#
# ---
#
# ## Phase 2: NIST 800-53 Control Mapping Engine
# **Estimated: 8-10 hours** | **Folder:** `phase-2-control-mapping/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `02-theory-and-lab-control-mapping.ipynb` | NIST control catalog (18 controls, 6 families), mapping engine, assessment logic, priority scoring | Ch. 2, 10 | DynamoDB, data modeling |
#
# **Deliverable:** ControlMappingEngine that maps findings to NIST controls with PASS/FAIL/PARTIAL status.
#
# ---
#
# ## Phase 3: Evidence PDF Generation
# **Estimated: 6-8 hours** | **Folder:** `phase-3-evidence-pdf/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `03-theory-and-lab-pdf-generation.ipynb` | ReportLab, Jinja2 templating, audit-ready formatting, Lambda layers, S3 presigned URLs | Ch. 10 | Lambda layers, S3 presigned URLs |
#
# **Deliverable:** PDF report generator that produces audit-ready compliance evidence packages.
#
# ---
#
# ## Phase 4: Storage, Drift Detection & Alerts
# **Estimated: 8-10 hours** | **Folder:** `phase-4-storage-drift/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `04-theory-and-lab-storage-drift.ipynb` | DynamoDB single-table design, S3 lifecycle policies, drift detection, SNS notifications, DynamoDB Streams | Ch. 3, 5, 11 | DynamoDB, S3, SNS, EventBridge |
#
# **Deliverable:** DriftDetector that compares scans over time and alerts on compliance regression.
#
# ---
#
# ## Phase 5: Executive Dashboard
# **Estimated: 8-10 hours** | **Folder:** `phase-5-dashboard/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `05-theory-and-lab-dashboard.ipynb` | REST API design, API Gateway + Lambda, Cognito auth, Streamlit/React dashboard, compliance visualizations | Ch. 1, 12 | API Gateway, Cognito, CloudFront |
#
# **Deliverable:** Working dashboard showing compliance posture over time.
#
# ---
#
# ## Phase 6: Infrastructure as Code & CI/CD
# **Estimated: 10-12 hours** | **Folder:** `phase-6-iac-deployment/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `06-theory-and-lab-terraform-cicd.ipynb` | Terraform modules, state management, GitHub Actions CI/CD, CloudWatch monitoring, X-Ray tracing | Ch. 1, 9 | CloudFormation, CodePipeline, CloudWatch, X-Ray |
#
# **Deliverable:** Full Terraform IaC deploying everything with CI/CD pipeline.
#
# ---
#
# ## Phase 7: Demo Environment & Go-to-Market
# **Estimated: 4-6 hours** | **Folder:** `phase-7-demo-gtm/`
#
# | Notebook | What You Learn | DDIA | DVA-C02 |
# |----------|----------------|------|---------|
# | `07-theory-and-lab-demo-gtm.ipynb` | Misconfigured test environment, live demo script, interview prep, SaaS business model, GTM strategy | — | — |
#
# **Deliverable:** A polished demo you can show interviewers or prospects. Business plan for the SaaS.
#
# ---

# %% [markdown]
# ## DVA-C02 Exam Coverage Map
#
# | Exam Domain (Weight) | Phases That Cover It |
# |----------------------|---------------------|
# | Domain 1: Development with AWS Services (32%) | Phase 1, 2, 3, 4, 5 |
# | Domain 2: Security (26%) | Phase 0, 1, 5, 6 |
# | Domain 3: Deployment (24%) | Phase 6, 7 |
# | Domain 4: Troubleshooting & Optimization (18%) | Phase 4, 5, 6 |
#
# ## DDIA Chapter Coverage Map
#
# | Chapter | Where It Shows Up |
# |---------|------------------|
# | Ch. 1: Reliable, Scalable, Maintainable | Phase 0 (design principles), Phase 5 (API), Phase 6 (IaC) |
# | Ch. 2: Data Models | Phase 0 (schema), Phase 2 (control mapping) |
# | Ch. 3: Storage & Retrieval | Phase 1 (Config as append log), Phase 4 (DynamoDB internals) |
# | Ch. 4: Encoding & Evolution | Phase 1 (ASFF format), Phase 5 (API versioning) |
# | Ch. 5: Replication | Phase 4 (DynamoDB replication, S3 durability) |
# | Ch. 9: Consistency & Consensus | Phase 6 (deployment consistency) |
# | Ch. 10: Batch Processing | Phase 2 (mapping engine), Phase 3 (PDF generation) |
# | Ch. 11: Stream Processing | Phase 0 (architecture), Phase 1 (event-driven), Phase 4 (drift) |
# | Ch. 12: Future of Data Systems | Phase 5 (derived data presentation) |
#
# ---
#
# ## Suggested Study Schedule (8 weeks)
#
# | Week | Phase | Hours | Also Study |
# |------|-------|-------|------------|
# | 1 | Phase 0: Foundations | 8 | DDIA Ch. 1-2, DVA-C02 Domain overview |
# | 2 | Phase 1: Data Collection | 10 | DDIA Ch. 3-4, DVA-C02 Lambda + IAM |
# | 3 | Phase 2: Control Mapping | 10 | DDIA Ch. 2, DVA-C02 DynamoDB deep dive |
# | 4 | Phase 3: PDF Generation | 8 | DDIA Ch. 10, DVA-C02 S3 + Lambda layers |
# | 5 | Phase 4: Storage & Drift | 10 | DDIA Ch. 5, 11, DVA-C02 Streams + SNS |
# | 6 | Phase 5: Dashboard | 10 | DDIA Ch. 12, DVA-C02 API GW + Cognito |
# | 7 | Phase 6: IaC & CI/CD | 12 | DDIA Ch. 9, DVA-C02 CloudFormation + CI/CD |
# | 8 | Phase 7: Demo & GTM | 6 | Full DVA-C02 practice exams |
#
# **Start here:** Open `phase-0-foundations/00-theory-compliance-and-architecture.ipynb`
